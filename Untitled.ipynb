# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
feature_importance = pd.read_csv("feature_importance-2021-03-29-14-28.csv")
feature_importance
# Out:
#                                               Feature  \
# 0                        saving_ratio_equal_frequency
# 1                             saving_ratio_reciprocal
# 2            account_check_status_no checking account
# 3                         credit_history_mean_encoder
# 4                         account_check_status_< 0 DM
# 5                   duration_in_month_equal_frequency
# 6   credit_history_critical account/ other credits...
# 7                             purpose_ordinal_encoder
# 8                             purpose_count_frequency
# 9                                savings_... < 100 DM
# 10                           property_count_frequency
# 11                           property_ordinal_encoder
# 12                                        housing_own
# 13                               property_real estate
# 14                savings_unknown/ no savings account
# 15                        purpose_domestic appliances
#
#     Individual_Feature_Importance  Pearson_Correlation  Spearman_Correlation  \
# 0                        0.785872             0.398174              0.395500
# 1                        0.757642            -0.153609             -0.402766
# 2                        0.669442            -0.317860             -0.317860
# 3                        0.640718             0.282946              0.261876
# 4                        0.632852             0.272951              0.272951
# 5                        0.621855             0.198116              0.192809
# 6                        0.609435            -0.223485             -0.223485
# 7                        0.591671             0.188018              0.197574
# 8                        0.591671            -0.035629             -0.059320
# 9                        0.588983             0.166764              0.166764
# 10                       0.579111            -0.085180             -0.068720
# 11                       0.579111             0.139351              0.137370
# 12                       0.566361            -0.132355             -0.132355
# 13                       0.557934            -0.118307             -0.118307
# 14                       0.554096            -0.126426             -0.126426
# 15                       0.552497            -0.107158             -0.107158
#
#     Kendall_Correlation
# 0              0.338785
# 1             -0.331451
# 2             -0.317860
# 3              0.246177
# 4              0.272951
# 5              0.168880
# 6             -0.223485
# 7              0.175703
# 8             -0.052754
# 9              0.166764
# 10            -0.063018
# 11             0.125973
# 12            -0.132355
# 13            -0.118307
# 14            -0.126426
# 15            -0.107158

# %%
permutation_feature_importance= pd.read_csv("permutation_feature_importance-2021-03-29-14-29.csv")

# %%
prediction_output = pd.read_csv("predictions_output-2021-03-29-14-30.csv")

# %%
summary_df = pd.read_csv("summary_df-2021-03-29-14-27.csv")

# %%
accuracy_report = pd.read_csv("accuracy_report-2021-03-29-14-28.csv")

# %%
accuracy_report
# Out:
#       TP     TN   FP    FN  Sensitivity  Specificity  Accuracy  \
# 0  520.0  130.0  4.0  96.0     0.992366     0.575221  0.866667
# 1  175.0   37.0  1.0  37.0     0.994318     0.500000  0.848000
#
#    Total_observations  Precision    Recall  F1_score  Log_loss  Roc_auc_score  \
# 0               750.0   0.992366  0.844156  0.912281  0.335341       0.931521
# 1               250.0   0.994318  0.825472  0.902062  0.385079       0.868090
#
#   Dataset
# 0   train
# 1    test

# %%
import numpy as np

# %%
cf_matrix = np.array([[accuracy_report["TN"][0],  accuracy_report["FP"][0]],
       [ accuracy_report["FN"][0], accuracy_report["TP"][0]]])

# %%
import seaborn as sns
labels = ["True Neg","False Pos","False Neg","True Pos"]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt="", cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
cf_matrix = np.array([[accuracy_report["TN"][0],  accuracy_report["FP"][0]],
       [ accuracy_report["FN"][0], accuracy_report["TP"][0]]])
group_names = ["True Neg","False Pos","False Neg","True Pos"]
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt="", cmap='Blues');

# %%
fig1, ax1 = plt.subplots(figsize=(7,5))
ax1 = sns.set_style("darkgrid")

cf_matrix1 = np.array([[accuracy_report["TN"][0], accuracy_report["FP"][0]],
                          [accuracy_report["FN"][0], accuracy_report["TP"][0]]])
group_names1 = ["True Neg", "False Pos", "False Neg", "True Pos"]
group_counts1 = ["{0:0.0f}".format(value) for value in  cf_matrix1.flatten()]
group_percentages1 = ["{0:.2%}".format(value) for value in cf_matrix1.flatten() / np.sum(cf_matrix1)]
labels1 = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names1, group_counts1, group_percentages1)]
labels1 = np.asarray(labels1).reshape(2, 2)
sns.heatmap(cf_matrix1, annot=labels1, fmt="", cmap='Blues');

# %%
my_dict={}

# %%
my_dict["dif"]=accuracy_report["Accuracy"][1]- accuracy_report["Accuracy"][0]

# %%
my_dict["dif"]
# Out:
# -0.01866666666666672

# %%
accuracy_report["Accuracy"][1]- accuracy_report["Accuracy"][0]
# Out:
# -0.01866666666666672

# %%
prediction_output
# Out:
#      saving_ratio_original account_check_status_original  \
# 0                     0.24                        < 0 DM
# 1                     0.28             0 <= ... < 200 DM
# 2                     0.42           no checking account
# 3                     0.07                        < 0 DM
# 4                     0.13                        < 0 DM
# ..                     ...                           ...
# 995                   0.29           no checking account
# 996                   0.06                        < 0 DM
# 997                   0.39           no checking account
# 998                   0.31                        < 0 DM
# 999                   0.32             0 <= ... < 200 DM
#
#      duration_in_month_original  \
# 0                             6
# 1                            48
# 2                            12
# 3                            42
# 4                            24
# ..                          ...
# 995                          12
# 996                          30
# 997                          12
# 998                          45
# 999                          45
#
#                                credit_history_original  \
# 0    critical account/ other credits existing (not ...
# 1             existing credits paid back duly till now
# 2    critical account/ other credits existing (not ...
# 3             existing credits paid back duly till now
# 4                      delay in paying off in the past
# ..                                                 ...
# 995           existing credits paid back duly till now
# 996           existing credits paid back duly till now
# 997           existing credits paid back duly till now
# 998           existing credits paid back duly till now
# 999  critical account/ other credits existing (not ...
#
#                  purpose_original             savings_original  \
# 0             domestic appliances  unknown/ no savings account
# 1             domestic appliances                 ... < 100 DM
# 2    (vacation - does not exist?)                 ... < 100 DM
# 3                radio/television                 ... < 100 DM
# 4                       car (new)                 ... < 100 DM
# ..                            ...                          ...
# 995              radio/television                 ... < 100 DM
# 996                    car (used)                 ... < 100 DM
# 997           domestic appliances                 ... < 100 DM
# 998           domestic appliances                 ... < 100 DM
# 999                    car (used)          100 <= ... < 500 DM
#
#                                      property_original housing_original    ID  \
# 0                                          real estate              own     1
# 1                                          real estate              own     2
# 2                                          real estate              own     3
# 3    if not A121 : building society savings agreeme...         for free     4
# 4                                unknown / no property         for free     5
# ..                                                 ...              ...   ...
# 995                                        real estate              own   996
# 996  if not A121 : building society savings agreeme...              own   997
# 997  if not A121/A122 : car or other, not in attrib...              own   998
# 998                              unknown / no property         for free   999
# 999  if not A121/A122 : car or other, not in attrib...              own  1000
#
#      saving_ratio_equal_frequency  ...  savings_unknown/ no savings account  \
# 0                               3  ...                                    1
# 1                               4  ...                                    0
# 2                               6  ...                                    0
# 3                               0  ...                                    0
# 4                               1  ...                                    0
# ..                            ...  ...                                  ...
# 995                             4  ...                                    0
# 996                             0  ...                                    0
# 997                             6  ...                                    0
# 998                             4  ...                                    0
# 999                             4  ...                                    0
#
#      property_real estate  housing_own  purpose_count_frequency  \
# 0                       1            1                 0.281333
# 1                       1            1                 0.281333
# 2                       1            1                 0.041333
# 3                       0            0                 0.190667
# 4                       0            0                 0.240000
# ..                    ...          ...                      ...
# 995                     1            1                 0.190667
# 996                     0            1                 0.105333
# 997                     0            1                 0.281333
# 998                     0            0                 0.281333
# 999                     0            1                 0.105333
#
#      property_count_frequency  purpose_ordinal_encoder  \
# 0                    0.280000                        2
# 1                    0.280000                        2
# 2                    0.280000                        9
# 3                    0.226667                        3
# 4                    0.160000                        5
# ..                        ...                      ...
# 995                  0.280000                        3
# 996                  0.226667                        0
# 997                  0.333333                        2
# 998                  0.160000                        2
# 999                  0.333333                        0
#
#      property_ordinal_encoder  credit_history_mean_encoder  predictions  \
# 0                           0                     0.137441     0.108123
# 1                           0                     0.335821     0.249195
# 2                           0                     0.137441     0.080390
# 3                           2                     0.335821     0.422053
# 4                           3                     0.309859     0.461895
# ..                        ...                          ...          ...
# 995                         0                     0.335821     0.086523
# 996                         2                     0.335821     0.342358
# 997                         1                     0.335821     0.104988
# 998                         3                     0.335821     0.425048
# 999                         1                     0.137441     0.138366
#
#      predictions_binary
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ..                  ...
# 995                   0
# 996                   0
# 997                   0
# 998                   0
# 999                   0
#
# [1000 rows x 27 columns]

# %%
my_dict={}
dataframelist=[feature_importance,permutation_feature_importance,prediction_output,summary_df,accuracy_report]
for l in dataframelist:
        for i in l.columns:
             my_dict[i]= list(l[i])

# %%
for i in feature_importance.columns[1:5]:
    print(i)
# Out:
# Individual_Feature_Importance
# Pearson_Correlation
# Spearman_Correlation
# Kendall_Correlation

# %%
my_dict.keys()
# Out:
# dict_keys(['Feature', 'Individual_Feature_Importance', 'Pearson_Correlation', 'Spearman_Correlation', 'Kendall_Correlation', 'Permutation_Importance_Train', 'Permutation_Importance_Test', 'Permutation_Importance_Std_Train', 'Permutation_Importance_Std_Test', 'saving_ratio_original', 'account_check_status_original', 'duration_in_month_original', 'credit_history_original', 'purpose_original', 'savings_original', 'property_original', 'housing_original', 'ID', 'saving_ratio_equal_frequency', 'duration_in_month_equal_frequency', 'saving_ratio_reciprocal', 'account_check_status_no checking account', 'account_check_status_< 0 DM', 'credit_history_critical account/ other credits existing (not at this bank)', 'purpose_domestic appliances', 'savings_... < 100 DM', 'savings_unknown/ no savings account', 'property_real estate', 'housing_own', 'purpose_count_frequency', 'property_count_frequency', 'purpose_ordinal_encoder', 'property_ordinal_encoder', 'credit_history_mean_encoder', 'predictions', 'predictions_binary', 'Column_Name', 'Unique_Data', 'Missing_Data', 'Missing_Percentage', 'Data_Types', 'Count', 'Mean', 'Std', 'Min', '25%', '50%', '75%', 'Max', 'TP', 'TN', 'FP', 'FN', 'Sensitivity', 'Specificity', 'Accuracy', 'Total_observations', 'Precision', 'Recall', 'F1_score', 'Log_loss', 'Roc_auc_score', 'Dataset'])

# %%
my_dict["TP"][0]
# Out:
# 520.0

# %%
accuracy_report[accuracy_report["Dataset"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9e357e9cede0> in <module>
# ----> 1 accuracy_report[accuracy_report["Dataset"]]
#
# NameError: name 'accuracy_report' is not defined

# %%
summary_df
# Out:
#                    Column_Name  Unique_Data  Missing_Data  Missing_Percentage  \
# 0                           ID         1000             0                 0.0
# 1                 saving_ratio          100             0                 0.0
# 2            debt_saving_ratio          100             0                 0.0
# 3                      default            2             0                 0.0
# 4         account_check_status            4             0                 0.0
# 5            duration_in_month           33             0                 0.0
# 6               credit_history            5             0                 0.0
# 7                      purpose           10             0                 0.0
# 8                credit_amount          921             0                 0.0
# 9                      savings            5             0                 0.0
# 10           present_emp_since            5             0                 0.0
# 11  installment_as_income_perc            4             0                 0.0
# 12         personal_status_sex            4             0                 0.0
# 13               other_debtors            3             0                 0.0
# 14           present_res_since            4             0                 0.0
# 15                    property            4             0                 0.0
# 16                         age           53             0                 0.0
# 17     other_installment_plans            3             0                 0.0
# 18                     housing            3             0                 0.0
# 19           credits_this_bank            4             0                 0.0
# 20                         job            4             0                 0.0
# 21    people_under_maintenance            2             0                 0.0
# 22                   telephone            2             0                 0.0
# 23              foreign_worker            2             0                 0.0
#
#    Data_Types                Count                 Mean                  Std  \
# 0      uint16               1000.0                500.5               288.82
# 1     float32               1000.0                 0.35                 0.23
# 2     float32               1000.0                 0.33                 0.23
# 3       uint8               1000.0                  0.3                 0.46
# 4      object  categorical_feature  categorical_feature  categorical_feature
# 5       uint8               1000.0                 20.9                12.06
# 6      object  categorical_feature  categorical_feature  categorical_feature
# 7      object  categorical_feature  categorical_feature  categorical_feature
# 8      uint16               1000.0              3271.26              2822.74
# 9      object  categorical_feature  categorical_feature  categorical_feature
# 10     object  categorical_feature  categorical_feature  categorical_feature
# 11      uint8               1000.0                 2.97                 1.12
# 12     object  categorical_feature  categorical_feature  categorical_feature
# 13     object  categorical_feature  categorical_feature  categorical_feature
# 14      uint8               1000.0                 2.84                  1.1
# 15     object  categorical_feature  categorical_feature  categorical_feature
# 16      uint8               1000.0                35.55                11.38
# 17     object  categorical_feature  categorical_feature  categorical_feature
# 18     object  categorical_feature  categorical_feature  categorical_feature
# 19      uint8               1000.0                 1.41                 0.58
# 20     object  categorical_feature  categorical_feature  categorical_feature
# 21      uint8               1000.0                 1.16                 0.36
# 22     object  categorical_feature  categorical_feature  categorical_feature
# 23     object  categorical_feature  categorical_feature  categorical_feature
#
#                     Min                  25%                  50%  \
# 0                   1.0               250.75                500.5
# 1                  0.02                 0.19                 0.32
# 2                   0.0                 0.17                  0.3
# 3                   0.0                  0.0                  0.0
# 4   categorical_feature  categorical_feature  categorical_feature
# 5                   4.0                 12.0                 18.0
# 6   categorical_feature  categorical_feature  categorical_feature
# 7   categorical_feature  categorical_feature  categorical_feature
# 8                 250.0               1365.5               2319.5
# 9   categorical_feature  categorical_feature  categorical_feature
# 10  categorical_feature  categorical_feature  categorical_feature
# 11                  1.0                  2.0                  3.0
# 12  categorical_feature  categorical_feature  categorical_feature
# 13  categorical_feature  categorical_feature  categorical_feature
# 14                  1.0                  2.0                  3.0
# 15  categorical_feature  categorical_feature  categorical_feature
# 16                 19.0                 27.0                 33.0
# 17  categorical_feature  categorical_feature  categorical_feature
# 18  categorical_feature  categorical_feature  categorical_feature
# 19                  1.0                  1.0                  1.0
# 20  categorical_feature  categorical_feature  categorical_feature
# 21                  1.0                  1.0                  1.0
# 22  categorical_feature  categorical_feature  categorical_feature
# 23  categorical_feature  categorical_feature  categorical_feature
#
#                     75%                  Max
# 0                750.25               1000.0
# 1                  0.46                 1.02
# 2                  0.44                  1.0
# 3                   1.0                  1.0
# 4   categorical_feature  categorical_feature
# 5                  24.0                 72.0
# 6   categorical_feature  categorical_feature
# 7   categorical_feature  categorical_feature
# 8               3972.25              18424.0
# 9   categorical_feature  categorical_feature
# 10  categorical_feature  categorical_feature
# 11                  4.0                  4.0
# 12  categorical_feature  categorical_feature
# 13  categorical_feature  categorical_feature
# 14                  4.0                  4.0
# 15  categorical_feature  categorical_feature
# 16                 42.0                 75.0
# 17  categorical_feature  categorical_feature
# 18  categorical_feature  categorical_feature
# 19                  2.0                  4.0
# 20  categorical_feature  categorical_feature
# 21                  1.0                  2.0
# 22  categorical_feature  categorical_feature
# 23  categorical_feature  categorical_feature

# %%
prediction_output[prediction_output["ID"].isin([1,2,3])]
# Out:
#    saving_ratio_original account_check_status_original  \
# 0                   0.24                        < 0 DM
# 1                   0.28             0 <= ... < 200 DM
# 2                   0.42           no checking account
#
#    duration_in_month_original  \
# 0                           6
# 1                          48
# 2                          12
#
#                              credit_history_original  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
#
#                purpose_original             savings_original  \
# 0           domestic appliances  unknown/ no savings account
# 1           domestic appliances                 ... < 100 DM
# 2  (vacation - does not exist?)                 ... < 100 DM
#
#   property_original housing_original  ID  saving_ratio_equal_frequency  ...  \
# 0       real estate              own   1                             3  ...
# 1       real estate              own   2                             4  ...
# 2       real estate              own   3                             6  ...
#
#    savings_unknown/ no savings account  property_real estate  housing_own  \
# 0                                    1                     1            1
# 1                                    0                     1            1
# 2                                    0                     1            1
#
#    purpose_count_frequency  property_count_frequency  purpose_ordinal_encoder  \
# 0                 0.281333                      0.28                        2
# 1                 0.281333                      0.28                        2
# 2                 0.041333                      0.28                        9
#
#    property_ordinal_encoder  credit_history_mean_encoder  predictions  \
# 0                         0                     0.137441     0.108123
# 1                         0                     0.335821     0.249195
# 2                         0                     0.137441     0.080390
#
#    predictions_binary
# 0                   0
# 1                   0
# 2                   0
#
# [3 rows x 27 columns]

# %%
my_dict["create chart1","create chart2"]=dict

# %%
for a,i in dict.items():
    print(a,i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-f5f841012b24> in <module>
# ----> 1 for a,i in dict.items():
#       2     print(a,i)
#
# TypeError: descriptor 'items' of 'dict' object needs an argument

# %%
my_dict["prediction_columns"]=prediction_output.columns
my_dict["create_chart"]=prediction_output.groupby("account_check_status_original")[["account_check_status_original","saving_ratio_original"]].mean().reset_index()
my_dict["create chart1"]=list(my_dict["create_chart"].iloc[:,0])
my_dict["create chart2"]=list(my_dict["create_chart"].iloc[:,1])

# %%
accuracy_report_transpose =accuracy_report.drop(["Sensitivity","Dataset"],axis=1).T.reset_index()

# %%
Accuracy Report TP
# Out:
#       TP     TN   FP    FN  Sensitivity  Specificity  Accuracy  \
# 0  520.0  130.0  4.0  96.0     0.992366     0.575221  0.866667
# 1  175.0   37.0  1.0  37.0     0.994318     0.500000  0.848000
#
#    Total_observations  Precision    Recall  F1_score  Log_loss  Roc_auc_score  \
# 0               750.0   0.992366  0.844156  0.912281  0.335341       0.931521
# 1               250.0   0.994318  0.825472  0.902062  0.385079       0.868090
#
#   Dataset
# 0   train
# 1    test

# %%
accuracy_report_transpose.columns=["indexes","train_accuracy_report","test_accuracy_report"]

# %%
accuracy_report_transpose
# Out:
#                indexes  train_accuracy_report  test_accuracy_report
# 0                   TP             520.000000            175.000000
# 1                   TN             130.000000             37.000000
# 2                   FP               4.000000              1.000000
# 3                   FN              96.000000             37.000000
# 4          Specificity               0.575221              0.500000
# 5             Accuracy               0.866667              0.848000
# 6   Total_observations             750.000000            250.000000
# 7            Precision               0.992366              0.994318
# 8               Recall               0.844156              0.825472
# 9             F1_score               0.912281              0.902062
# 10            Log_loss               0.335341              0.385079
# 11       Roc_auc_score               0.931521              0.868090

# %%
summary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-112-9366b5a69b1e> in <module>
# ----> 1 summary
#
# NameError: name 'summary' is not defined

# %%
class DataStore():
    feature_importance = pd.read_csv("feature_importance-2021-03-29-14-28.csv")
    permutation_feature_importance = pd.read_csv("permutation_feature_importance-2021-03-29-14-29.csv")
    prediction_output = pd.read_csv("predictions_output-2021-03-29-14-30.csv")
    summary_df = pd.read_csv("summary_df-2021-03-29-14-27.csv")
    accuracy_report = pd.read_csv("accuracy_report-2021-03-29-14-28.csv")
    my_dict = {}
    dataframelist=None
    round_list=None
    select_box=[]
    select_box1=[]
    url = None

data = DataStore()

# %%
data.my_dict["prediction_columns"] = data.prediction_output.columns
data.my_dict["prediction_output_numeric_columns"] = data.prediction_output.select_dtypes(exclude=['object']).columns
data.my_dict["prediction_output_categorical_columns"] = data.prediction_output.select_dtypes(include=['object']).columns

# %%
data.my_dict["prediction_columns"].insert(0,"Select Feature")
# Out:
# Index(['Select Feature', 'saving_ratio_original',
#        'account_check_status_original', 'duration_in_month_original',
#        'credit_history_original', 'purpose_original', 'savings_original',
#        'property_original', 'housing_original', 'ID',
#        'saving_ratio_equal_frequency', 'duration_in_month_equal_frequency',
#        'saving_ratio_reciprocal', 'account_check_status_no checking account',
#        'account_check_status_< 0 DM',
#        'credit_history_critical account/ other credits existing (not at this bank)',
#        'purpose_domestic appliances', 'savings_... < 100 DM',
#        'savings_unknown/ no savings account', 'property_real estate',
#        'housing_own', 'purpose_count_frequency', 'property_count_frequency',
#        'purpose_ordinal_encoder', 'property_ordinal_encoder',
#        'credit_history_mean_encoder', 'predictions', 'predictions_binary'],
#       dtype='object')

# %%
data.prediction_output[data.prediction_output["ID"].isin([1,4,8])].reset_index()
# Out:
#    index  saving_ratio_original account_check_status_original  \
# 0      0                   0.24                        < 0 DM
# 1      3                   0.07                        < 0 DM
# 2      7                   0.46             0 <= ... < 200 DM
#
#    duration_in_month_original  \
# 0                           6
# 1                          42
# 2                          36
#
#                              credit_history_original     purpose_original  \
# 0  critical account/ other credits existing (not ...  domestic appliances
# 1           existing credits paid back duly till now     radio/television
# 2           existing credits paid back duly till now           car (used)
#
#               savings_original  \
# 0  unknown/ no savings account
# 1                 ... < 100 DM
# 2                 ... < 100 DM
#
#                                    property_original housing_original  ID  \
# 0                                        real estate              own   1
# 1  if not A121 : building society savings agreeme...         for free   4
# 2  if not A121/A122 : car or other, not in attrib...             rent   8
#
#    ...  savings_unknown/ no savings account  property_real estate  \
# 0  ...                                    1                     1
# 1  ...                                    0                     0
# 2  ...                                    0                     0
#
#    housing_own  purpose_count_frequency  property_count_frequency  \
# 0            1                 0.281333                  0.280000
# 1            0                 0.190667                  0.226667
# 2            0                 0.105333                  0.333333
#
#    purpose_ordinal_encoder  property_ordinal_encoder  \
# 0                        2                         0
# 1                        3                         2
# 2                        0                         1
#
#    credit_history_mean_encoder  predictions  predictions_binary
# 0                     0.137441     0.108123                   0
# 1                     0.335821     0.422053                   0
# 2                     0.335821     0.284346                   0
#
# [3 rows x 28 columns]

# %%
    try:
        data.select_box = request.form.get("one")
        if len(data.select_box) == 1:
            data.select_box = data.select_box[0]
        data.select_box = data.select_box[0]
        data.select_box1 = request.form.get("ones")
        data.select_box1 = data.select_box1[0]


    except:
        data.select_box = data.my_dict["prediction_output_categorical_columns"][0]
        data.select_box1 = data.my_dict["prediction_output_numeric_columns"][0]

# %%
    try:
        data.select_box = request.form.getlist("one")
        if len(data.select_box) == 1:
            data.select_box = data.select_box[0]
        data.select_box = data.select_box[0]
        data.select_box1 = request.form.getlist("ones")
        data.select_box1 = data.select_box1[0]


    except:
        data.select_box = data.my_dict["prediction_output_categorical_columns"][0]
        data.select_box1 = data.my_dict["prediction_output_numeric_columns"][0]



    try:
        if data.select_box not in data.my_dict["prediction_output_numeric_columns"]:

                a = data.select_box
                b = data.select_box1
                data.my_dict["a"] = a
                data.my_dict["b"] = b
                data.my_dict_df = data.prediction_output.groupby(a)[b].mean().reset_index()
                data.my_dict["create label1"] = list(data.my_dict_df.iloc[:, 0])
                data.my_dict["create chart2"] = list(data.my_dict_df.iloc[:, 1])
                
                data.my_dict["chart_type"] = "bar"
        else:

                a = data.select_box
                b = data.select_box1
                data.my_dict["a"] = a
                data.my_dict["b"] = b
                data.my_dict["create label1"] = list(data.my_dict_df.loc[:, a])
                data.my_dict["create chart2"] = list(data.my_dict_df.loc[:, b])
                
                data.my_dict["chart_type"] = "line"
    except:
        pass

# %%
create_chart()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-64-46c523712c84> in create_chart()
#       5             data.my_dict["create_chart"] = data.prediction_output.groupby(data.select_box)[
# ----> 6                 data.select_box1].mean().reset_index()
#       7         except:
#
# c:\users\mwolf\anaconda3\envs\charts_projects\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, numeric_only)
#    1498             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
# -> 1499             numeric_only=numeric_only,
#    1500         )
#
# c:\users\mwolf\anaconda3\envs\charts_projects\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1080         if not output:
# -> 1081             raise DataError("No numeric types to aggregate")
#    1082
#
# DataError: No numeric types to aggregate
#
# During handling of the above exception, another exception occurred:
#
# DataError                                 Traceback (most recent call last)
# <ipython-input-65-639b94031cf0> in <module>
# ----> 1 create_chart()
#
# <ipython-input-64-46c523712c84> in create_chart()
#       9             data.select_box = data.my_dict["prediction_output_numeric_columns"][0]
#      10             data.select_box1 = data.my_dict["prediction_output_categorical_columns"][2]
# ---> 11             data.my_dict["create_chart"] = data.prediction_output.groupby(data.select_box)[data.select_box1].mean().reset_index()
#      12
#      13         data.my_dict["create label1"] = list(data.my_dict["create_chart"].iloc[:, 0])
#
# c:\users\mwolf\anaconda3\envs\charts_projects\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, numeric_only)
#    1497             "mean",
#    1498             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
# -> 1499             numeric_only=numeric_only,
#    1500         )
#    1501
#
# c:\users\mwolf\anaconda3\envs\charts_projects\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1079
#    1080         if not output:
# -> 1081             raise DataError("No numeric types to aggregate")
#    1082
#    1083         return self._wrap_aggregated_output(output, index=self.grouper.result_index)
#
# DataError: No numeric types to aggregate
